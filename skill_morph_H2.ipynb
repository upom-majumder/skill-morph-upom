# %% [markdown]
# <a href="https://colab.research.google.com/github/upom-majumder/skill-morph-upom/blob/main/skill_morph_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# H1: subtraction, multiplication and division

num1 = int(input("num1: "))
num2 = int(input("num2: "))


subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2



print(subtraction)
print(multiplication)
print(division)
# Out:
# num1: 50
# num2: 10
# 40
# 500
# 5.0

# %%
#H2 id, name, batch and hometown

id= 204550              # Int
name = "Upom majumder"  # Str
batch = "Botany-JU50"   # Str
hometown = "Gazipur"    # Str

print(id, name, batch, hometown)
# Out:
# 204550 Upom majumder Botany-JU50 Gazipur

# %%
#H3 Write a program to change values of an integer variable
num= 125
print(num + 1)
# Out:
# 126

# %%
# H4: Converting string numbers to integers
num1= "20"   #str
num2= "30"   #str
total = int(num1) + int(num2)
print(total)
# Out:
# 50

# %%
# H5: Average of three numbers rounded to two decimal places
n1 = 10
n2 = 15
n3 = 22
average = (n1 + n2 + n3) / 3
print(round(average, 2))
# Out:
# 15.67

# %%
# H6 Get numbers and the operation choice from the user
num1 = float(input("first number: "))
num2 = float(input("second number: "))
operation = input("operation (+, -, *, /): ")
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
print(operation, addition, subtraction, division)
# Out:
# first number: 10
# second number: 5
# operation (+, -, *, /): *
# * 15.0 5.0 2.0

# %%
#H7 determines whether it is a vowel or a consonant.
word = str(input("enter a letter :")).lower()
if word in ('a', 'e', 'i', 'o', 'u'):
  print ("The word is vowel")
else:
  print ("The word is consonant")
# Out:
# enter a letter :M
# The word is consonant

# %%
#H8 converts temperatures between Fahrenheit and Celsius based on user input.

celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(fahrenheit, "F")

fahrenheit = float(input("Enter temperature in Fahrenheit: "))
celsius = (fahrenheit - 32) * 5/9
print(celsius, "C")
# Out:
# Enter temperature in Celsius: 40
# 104.0 F
# Enter temperature in Fahrenheit: 101
# 38.333333333333336 C

# %%
# H9: Find the largest from three numbers

num1 = int(input("first number: "))
num2 = int(input("second number: "))
num3 = int(input("third number: "))

if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3

print("The largest number is", largest)
# Out:
# first number: 60
# second number: 65
# third number: 53
# The largest number is 65

# %%
#H10
N = int(input("a number: "))

for i in range(1, N + 1):
    if i % 2 == 0:
        print(i)
# Out:
# a number: 10
# 2
# 4
# 6
# 8
# 10

# %%
#H11
N = int(input("a number: "))

total = 0
for i in range(1, N + 1):
    if i % 3 == 0 or i % 5 == 0:
        total += i
print("Sum =", total)
# Out:
# a number: 100
# Sum = 2418

# %%
#H12
n = int(input("Enter a number: "))

# Print multiplication table from 1 to 10
for i in range(1, 11):
    print(n, "x", i, "=", n * i)
# Out:
# Enter a number: 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
