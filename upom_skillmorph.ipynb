# %% [markdown]
# <a href="https://colab.research.google.com/github/upom-majumder/skill-morph-upom/blob/main/upom_skillmorph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("welcome to skillmorph")
# Out:
# welcome to skillmorph
